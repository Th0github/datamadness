# %% [markdown]
# ## Estimate how many copies of a game has sold on steam on reviews
# Steam sale data is not public.  Historically, game marketing companies have used a metric called the Boxleiter number which was most recently updated in 2018 [3].  In October 2019, Steam introduced a 'would you like to review this?' button directly to a games launch page.  This button's existence would imply that games with higher reviews would also mean that there are more sales.
#
# The sample dataset for the number of people who own a game come from SteamSpy, a third party source.  So any analysis made should be taken with a grain of salt.

# %%
# imports and setup

import scipy as sc
import numpy as np
from scipy.stats import norm
import seaborn as sns

import pandas as pd
import statsmodels.formula.api as sm
from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6)

from sklearn.model_selection import train_test_split
from statsmodels.tools import add_constant
import statsmodels.api as sm1 #for multiple regression

# %%
df = pd.read_csv('data/clean_steam_general.csv')

# %%
# correlation plot seaborn
df.head()
# Out:
#                    QueryName               ResponseName ReleaseDate  \
# 0             Counter-Strike             Counter-Strike  Nov 1 2000
# 1      Team Fortress Classic      Team Fortress Classic  Apr 1 1999
# 2              Day of Defeat              Day of Defeat  May 1 2003
# 3         Deathmatch Classic         Deathmatch Classic  Jun 1 2001
# 4  Half-Life: Opposing Force  Half-Life: Opposing Force  Nov 1 1999
#
#    RequiredAge  Metacritic  RecommendationCount  ScreenshotCount  \
# 0            0          88                68991               13
# 1            0           0                 2439                5
# 2            0          79                 2319                5
# 3            0           0                  888                4
# 4            0           0                 2934                5
#
#    SteamSpyOwners  SteamSpyOwnersVariance  SteamSpyPlayersEstimate  ...  \
# 0        13033334                   92789                  9140731  ...
# 1         5399140                   60368                   753627  ...
# 2         7621102                   71499                  1709740  ...
# 3         7498965                   70936                   789676  ...
# 4         5399499                   60370                   705741  ...
#
#    PurchaseAvail  SubscriptionAvail  PlatformWindows  PlatformLinux  \
# 0           True              False             True           True
# 1           True              False             True           True
# 2           True              False             True           True
# 3           True              False             True           True
# 4           True              False             True           True
#
#    PlatformMac  GenreIsEarlyAccess  GenreIsFreeToPlay  PriceCurrency  \
# 0         True               False              False            USD
# 1         True               False              False            USD
# 2         True               False              False            USD
# 3         True               False              False            USD
# 4         True               False              False            USD
#
#    PriceInitial  PriceFinal
# 0          9.99        9.99
# 1          4.99        4.99
# 2          4.99        4.99
# 3          4.99        4.99
# 4          4.99        4.99
#
# [5 rows x 23 columns]

# %%
# we don't neccessarily care about the name of the game
df_sales = df[['Metacritic', 'RecommendationCount', 'SteamSpyOwners','SteamSpyOwnersVariance', 'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance', 'IsFree', 'PurchaseAvail', 'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'PriceInitial', 'PriceFinal']]
df_sales.head()
# Out:
#    Metacritic  RecommendationCount  SteamSpyOwners  SteamSpyOwnersVariance  \
# 0          88                68991        13033334                   92789
# 1           0                 2439         5399140                   60368
# 2          79                 2319         7621102                   71499
# 3           0                  888         7498965                   70936
# 4           0                 2934         5399499                   60370
#
#    SteamSpyPlayersEstimate  SteamSpyPlayersVariance  IsFree  PurchaseAvail  \
# 0                  9140731                    78136   False           True
# 1                   753627                    22699   False           True
# 2                  1709740                    34145   False           True
# 3                   789676                    23235   False           True
# 4                   705741                    21968   False           True
#
#    PlatformWindows  PlatformLinux  PlatformMac  GenreIsEarlyAccess  \
# 0             True           True         True               False
# 1             True           True         True               False
# 2             True           True         True               False
# 3             True           True         True               False
# 4             True           True         True               False
#
#    GenreIsFreeToPlay  PriceInitial  PriceFinal
# 0              False          9.99        9.99
# 1              False          4.99        4.99
# 2              False          4.99        4.99
# 3              False          4.99        4.99
# 4              False          4.99        4.99

# %%
# remove any outliers in metacritic score, recommendationcount, steamspyowners, steamspyplayerestimate

#check if the datatypes are correct
print(df_sales.dtypes[['Metacritic', 'RecommendationCount', 'SteamSpyOwners','SteamSpyOwnersVariance', 'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance', 'IsFree', 'PurchaseAvail', 'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'PriceInitial', 'PriceFinal']])
#df_sales['ResponseName'] = df_sales['ResponseName'].astype(str) 

# keep only the ones that are within +3 to -3 standard deviations in the columns 'Metacritic', 'RecommendationCount', 'SteamSpyOwners', 'SteamSpyPlayersEstimate', 
df_sales = df_sales[np.abs(df_sales['Metacritic']-df_sales['Metacritic'].mean()) <= (3*df_sales['Metacritic'].std())]
df_sales = df_sales[np.abs(df_sales['RecommendationCount']-df_sales['RecommendationCount'].mean()) <= (3*df_sales['RecommendationCount'].std())]
df_sales = df_sales[np.abs(df_sales['SteamSpyOwners']-df_sales['SteamSpyOwners'].mean()) <= (3*df_sales['SteamSpyOwners'].std())]
df_sales = df_sales[np.abs(df_sales['SteamSpyPlayersEstimate']-df_sales['SteamSpyPlayersEstimate'].mean()) <= (3*df_sales['SteamSpyPlayersEstimate'].std())]
# Out:
# Metacritic                   int64
# RecommendationCount          int64
# SteamSpyOwners               int64
# SteamSpyOwnersVariance       int64
# SteamSpyPlayersEstimate      int64
# SteamSpyPlayersVariance      int64
# IsFree                        bool
# PurchaseAvail                 bool
# PlatformWindows               bool
# PlatformLinux                 bool
# PlatformMac                   bool
# GenreIsEarlyAccess            bool
# GenreIsFreeToPlay             bool
# PriceInitial               float64
# PriceFinal                 float64
# dtype: object

# %% [markdown]
# ## EDA

# %%
# EDA of sales data
df_sales.describe()
# Out:
#          Metacritic  RecommendationCount  SteamSpyOwners  \
# count  12790.000000         12790.000000    1.279000e+04
# mean      10.383112           314.277561    5.945671e+04
# std       25.335544          1259.770790    1.358313e+05
# min        0.000000             0.000000    0.000000e+00
# 25%        0.000000             0.000000    7.170000e+02
# 50%        0.000000             0.000000    8.250000e+03
# 75%        0.000000           191.000000    4.555500e+04
# max       94.000000         44352.000000    1.635130e+06
#
#        SteamSpyOwnersVariance  SteamSpyPlayersEstimate  \
# count            12790.000000             12790.000000
# mean              4088.007819             30504.859812
# std               4899.656060             69730.264776
# min                  0.000000                 0.000000
# 25%                858.000000               533.000000
# 50%               2377.000000              3408.000000
# 75%               5586.000000             20805.000000
# max              33395.000000            484961.000000
#
#        SteamSpyPlayersVariance  PriceInitial    PriceFinal
# count             12790.000000  12790.000000  12790.000000
# mean               2894.905864      8.848099      8.503396
# std                3545.782653     14.216930     13.508905
# min                   0.000000      0.000000      0.000000
# 25%                 740.000000      1.990000      1.990000
# 50%                1567.000000      5.990000      4.990000
# 75%                3775.000000      9.990000      9.990000
# max               18216.000000    449.990000    449.990000

# %%
# bar and pie charts to get a general outline of the data
df_sales['PropType'].value_counts().plot(kind='bar')
plt.ylabel('count')
df_sales['PropType'].value_counts().plot(kind='pie')

# %%
corr = df_sales.corr()
print(corr)
# Out:
#                          Metacritic  RecommendationCount  SteamSpyOwners  \
# Metacritic                 1.000000             0.206436        0.381336
# RecommendationCount        0.206436             1.000000        0.380106
# SteamSpyOwners             0.381336             0.380106        1.000000
# SteamSpyOwnersVariance     0.442308             0.385891        0.919436
# SteamSpyPlayersEstimate    0.386289             0.498162        0.888300
# SteamSpyPlayersVariance    0.444223             0.454009        0.851495
# IsFree                    -0.073051             0.038733        0.181196
# PurchaseAvail              0.172834             0.055375        0.023185
# PlatformWindows            0.005125             0.002142        0.002527
# PlatformLinux              0.039227             0.031120        0.016672
# PlatformMac                0.055040             0.040123        0.052537
# GenreIsEarlyAccess        -0.144054            -0.029138       -0.090078
# GenreIsFreeToPlay         -0.058641             0.060972        0.210933
# PriceInitial               0.155440             0.142535        0.052454
# PriceFinal                 0.147103             0.144429        0.040700
#
#                          SteamSpyOwnersVariance  SteamSpyPlayersEstimate  \
# Metacritic                             0.442308                 0.386289
# RecommendationCount                    0.385891                 0.498162
# SteamSpyOwners                         0.919436                 0.888300
# SteamSpyOwnersVariance                 1.000000                 0.867510
# SteamSpyPlayersEstimate                0.867510                 1.000000
# SteamSpyPlayersVariance                0.950170                 0.931472
# IsFree                                 0.216702                 0.156370
# PurchaseAvail                          0.092642                 0.034488
# PlatformWindows                        0.001983                 0.002657
# PlatformLinux                          0.041831                 0.043181
# PlatformMac                            0.085168                 0.070371
# GenreIsEarlyAccess                    -0.123976                -0.068720
# GenreIsFreeToPlay                      0.247755                 0.198940
# PriceInitial                           0.072549                 0.091255
# PriceFinal                             0.057486                 0.084077
#
#                          SteamSpyPlayersVariance    IsFree  PurchaseAvail  \
# Metacritic                              0.444223 -0.073051       0.172834
# RecommendationCount                     0.454009  0.038733       0.055375
# SteamSpyOwners                          0.851495  0.181196       0.023185
# SteamSpyOwnersVariance                  0.950170  0.216702       0.092642
# SteamSpyPlayersEstimate                 0.931472  0.156370       0.034488
# SteamSpyPlayersVariance                 1.000000  0.175570       0.109756
# IsFree                                  0.175570  1.000000      -0.518674
# PurchaseAvail                           0.109756 -0.518674       1.000000
# PlatformWindows                         0.002033  0.003471      -0.006026
# PlatformLinux                           0.064964 -0.004339       0.012395
# PlatformMac                             0.099407 -0.001180       0.016588
# GenreIsEarlyAccess                     -0.101433 -0.002489      -0.036623
# GenreIsFreeToPlay                       0.225190  0.742728      -0.416383
# PriceInitial                            0.110920 -0.162680       0.299896
# PriceFinal                              0.099988 -0.164123       0.303319
#
#                          PlatformWindows  PlatformLinux  PlatformMac  \
# Metacritic                      0.005125       0.039227     0.055040
# RecommendationCount             0.002142       0.031120     0.040123
# SteamSpyOwners                  0.002527       0.016672     0.052537
# SteamSpyOwnersVariance          0.001983       0.041831     0.085168
# SteamSpyPlayersEstimate         0.002657       0.043181     0.070371
# SteamSpyPlayersVariance         0.002033       0.064964     0.099407
# IsFree                          0.003471      -0.004339    -0.001180
# PurchaseAvail                  -0.006026       0.012395     0.016588
# PlatformWindows                 1.000000      -0.008279    -0.004362
# PlatformLinux                  -0.008279       1.000000     0.657100
# PlatformMac                    -0.004362       0.657100     1.000000
# GenreIsEarlyAccess              0.004444      -0.018556    -0.037728
# GenreIsFreeToPlay               0.002646      -0.016441     0.004280
# PriceInitial                   -0.018598      -0.014052    -0.007663
# PriceFinal                     -0.019892      -0.018228    -0.017215
#
#                          GenreIsEarlyAccess  GenreIsFreeToPlay  PriceInitial  \
# Metacritic                        -0.144054          -0.058641      0.155440
# RecommendationCount               -0.029138           0.060972      0.142535
# SteamSpyOwners                    -0.090078           0.210933      0.052454
# SteamSpyOwnersVariance            -0.123976           0.247755      0.072549
# SteamSpyPlayersEstimate           -0.068720           0.198940      0.091255
# SteamSpyPlayersVariance           -0.101433           0.225190      0.110920
# IsFree                            -0.002489           0.742728     -0.162680
# PurchaseAvail                     -0.036623          -0.416383      0.299896
# PlatformWindows                    0.004444           0.002646     -0.018598
# PlatformLinux                     -0.018556          -0.016441     -0.014052
# PlatformMac                       -0.037728           0.004280     -0.007663
# GenreIsEarlyAccess                 1.000000           0.012921      0.007984
# GenreIsFreeToPlay                  0.012921           1.000000     -0.130325
# PriceInitial                       0.007984          -0.130325      1.000000
# PriceFinal                         0.012508          -0.131757      0.956905
#
#                          PriceFinal
# Metacritic                 0.147103
# RecommendationCount        0.144429
# SteamSpyOwners             0.040700
# SteamSpyOwnersVariance     0.057486
# SteamSpyPlayersEstimate    0.084077
# SteamSpyPlayersVariance    0.099988
# IsFree                    -0.164123
# PurchaseAvail              0.303319
# PlatformWindows           -0.019892
# PlatformLinux             -0.018228
# PlatformMac               -0.017215
# GenreIsEarlyAccess         0.012508
# GenreIsFreeToPlay         -0.131757
# PriceInitial               0.956905
# PriceFinal                 1.000000

# %%
#correlation heatmap
#the darker the color the worse the correlation
sns.heatmap(corr)
plt.show()

# %%
scatter_matrix = sns.pairplot(df_sales[['Metacritic', 'RecommendationCount', 'SteamSpyOwners','SteamSpyOwnersVariance', 'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance', 'IsFree', 'PurchaseAvail', 'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'PriceInitial', 'PriceFinal']])
plt.savefig('sales_scatter.jpg') #saving plot since this takes awhile to run
# warning is just numpy converting the boolean to [0,1]
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
# fit regression model with statsmodel
reg = sm.ols(formula="SoldPrice ~ LstPrice", data=df_sales).fit()
reg.summary()

# %%
par1 = dict(reg.params)

plt.scatter(df_sales['LstPrice'],h_demo1['SoldPrice'],color='black',label="data")
x = np.linspace(0, 1200000)
y1 = par1["Intercept"] + par1['LstPrice']*x

plt.plot(x,y1,label="Predicted listing price",linewidth=2)
plt.legend()
plt.xlabel('LstPrice'); plt.ylabel('SoldPrice')
#plt.ylim((0,50))
plt.show()
print(par1)

# %%
#do something with scatterplots and the booleans just to see if there is something there
#maybe even do some Dimensionality reduction
sns.scatterplot(data=h_demo1, x="TotSqf", y="SoldPrice", hue='Prop_Type_num')
plt.xlabel('TotSqf')
plt.ylabel('SoldPrice')
plt.title('Prop Type vs. TotSqf')

# %%
# try PCA with the genre
from sklearn.preprocessing import scale

# scale the dataset
heptn = hept.drop(['name ',' score '],axis=1)
X = scale(heptn.values)
#X = scale(hept.drop(['name ',' score '],axis=1).values)

# find PCA and transform to new coordinates
pca_model = PCA()
X_PCA = pca_model.fit_transform(X)

# create a new pandas dataframe 
df_plot = pd.DataFrame(X_PCA, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7'])
df_plot

# %%
pca_loadings = pd.DataFrame(pca_model.components_.T, index=heptn.columns, columns=['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7'])
pca_loadings

# %%
# What best explains SteamSpyOwners -> counter Boxleiter number
# Secondary analysis -> what best explains SteamSpyPlayerEstimate

# %% [markdown]
# Sources:
#
# [1] https://newsletter.gamediscover.co/p/how-that-game-sold-on-steam-using
#
# [2] http://greyaliengames.com/blog/how-to-estimate-how-many-sales-a-steam-game-has-made/
#
# [3] https://www.gamasutra.com/blogs/JakeBirkett/20180504/317366/Using_Steam_reviews_to_estimate_sales.php
